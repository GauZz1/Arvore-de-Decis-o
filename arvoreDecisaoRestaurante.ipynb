# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('restaurantev2.csv', delimiter=';') # colect data form database

# %%
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix

# %%
X = data.drop(['Chuva', 'Exemplo'], axis=1); # remove 'Chuva' and 'Exemplo' from 'data' and atributes to X 
Y = data['Chuva'].map({'Sim': 1, 'Não': 0}); # create a new table with 'Chuva' atributte where Sim = 1 e Não = 0

xtr, Xval, ytr, yval = train_test_split(X, Y, test_size=0.5, random_state=0);

ohe = preprocessing.OneHotEncoder(sparse=False) # define OnHotEncoder

encoded_x = ohe.fit_transform(X) # transform table X to binary

arvore = DecisionTreeClassifier()
arvore = arvore.fit(encoded_x, Y) # create tree

p = arvore.predict(encoded_x)

np.sqrt(confusion_matrix(p, Y))
# Out:
# array([[2.64575131, 0.        ],
#        [0.        , 2.23606798]])

# %%
plot_tree(arvore)
# Out:
# [Text(0.6, 0.9285714285714286, 'X[12] <= 0.5\ngini = 0.486\nsamples = 12\nvalue = [7, 5]'),
#  Text(0.4, 0.7857142857142857, 'X[11] <= 0.5\ngini = 0.42\nsamples = 10\nvalue = [7, 3]'),
#  Text(0.2, 0.6428571428571429, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.6, 0.6428571428571429, 'X[21] <= 0.5\ngini = 0.49\nsamples = 7\nvalue = [4, 3]'),
#  Text(0.4, 0.5, 'X[4] <= 0.5\ngini = 0.48\nsamples = 5\nvalue = [2, 3]'),
#  Text(0.2, 0.35714285714285715, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.6, 0.35714285714285715, 'X[8] <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.4, 0.21428571428571427, 'X[17] <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.2, 0.07142857142857142, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6, 0.07142857142857142, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.8, 0.21428571428571427, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.8, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
# ...
