# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('weather.nominal.csv', delimiter=',') # colect data form database

# %%
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix

# %%
X = data.drop(['play'], axis=1); # remove 'Chuva' and 'Exemplo' from 'data' and atributes to X 
Y = data['play'].map({'yes': 1, 'no': 0}); # create a new table with 'Chuva' atributte where Sim = 1 e Não = 0

xtr, Xval, ytr, yval = train_test_split(X, Y, test_size=0.5, random_state=0);

ohe = preprocessing.OneHotEncoder(sparse=False) # define OnHotEncoder

encoded_x = ohe.fit_transform(X) # transform table X to binary

arvore = DecisionTreeClassifier()
arvore = arvore.fit(encoded_x, Y) # create tree

p = arvore.predict(encoded_x)

np.sqrt(confusion_matrix(p, Y))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /home/wyan/Documents/IA/Arvore de Decisão/arvoreDecisao.ipynb Cell 4 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/home/wyan/Documents/IA/Arvore%20de%20Decis%C3%A3o/arvoreDecisao.ipynb#W3sZmlsZQ%3D%3D?line=0'>1</a> X = data.drop(['play'], axis=1); # remove 'Chuva' and 'Exemplo' from 'data' and atributes to X
#       <a href='vscode-notebook-cell:/home/wyan/Documents/IA/Arvore%20de%20Decis%C3%A3o/arvoreDecisao.ipynb#W3sZmlsZQ%3D%3D?line=1'>2</a> Y = data['play'].map({'yes': 1, 'no': 0}); # create a new table with 'Chuva' atributte where Sim = 1 e Não = 0
#       <a href='vscode-notebook-cell:/home/wyan/Documents/IA/Arvore%20de%20Decis%C3%A3o/arvoreDecisao.ipynb#W3sZmlsZQ%3D%3D?line=3'>4</a> xtr, Xval, ytr, yval = train_test_split(X, Y, test_size=0.5, random_state=0);
#
# File /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py:4954, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4806 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    4807 def drop(
#    4808     self,
#    (...)
#    4815     errors: str = "raise",
#    4816 ):
#    4817     """
#    4818     Drop specified labels from rows or columns.
#    4819
#    (...)
#    4952             weight  1.0     0.8
#    4953     """
# -> 4954     return super().drop(
#    4955         labels=labels,
#    4956         axis=axis,
#    4957         index=index,
#    4958         columns=columns,
#    4959         level=level,
#    4960         inplace=inplace,
#    4961         errors=errors,
#    4962     )
#
# File /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py:4267, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4265 for axis, labels in axes.items():
#    4266     if labels is not None:
# -> 4267         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4269 if inplace:
#    4270     self._update_inplace(obj)
#
# File /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py:4311, in NDFrame._drop_axis(self, labels, axis, level, errors, consolidate, only_slice)
#    4309         new_axis = axis.drop(labels, level=level, errors=errors)
#    4310     else:
# -> 4311         new_axis = axis.drop(labels, errors=errors)
#    4312     indexer = axis.get_indexer(new_axis)
#    4314 # Case for non-unique axis
#    4315 else:
#
# File /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py:6644, in Index.drop(self, labels, errors)
#    6642 if mask.any():
#    6643     if errors != "ignore":
# -> 6644         raise KeyError(f"{list(labels[mask])} not found in axis")
#    6645     indexer = indexer[~mask]
#    6646 return self.delete(indexer)
#
# KeyError: "['play'] not found in axis"

# %%
plot_tree(arvore)
# Out:
# [Text(0.6, 0.9285714285714286, 'X[12] <= 0.5\ngini = 0.486\nsamples = 12\nvalue = [7, 5]'),
#  Text(0.4, 0.7857142857142857, 'X[11] <= 0.5\ngini = 0.42\nsamples = 10\nvalue = [7, 3]'),
#  Text(0.2, 0.6428571428571429, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.6, 0.6428571428571429, 'X[21] <= 0.5\ngini = 0.49\nsamples = 7\nvalue = [4, 3]'),
#  Text(0.4, 0.5, 'X[4] <= 0.5\ngini = 0.48\nsamples = 5\nvalue = [2, 3]'),
#  Text(0.2, 0.35714285714285715, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.6, 0.35714285714285715, 'X[2] <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.4, 0.21428571428571427, 'X[8] <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.2, 0.07142857142857142, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6, 0.07142857142857142, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.8, 0.21428571428571427, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.8, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.8, 0.7857142857142857, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]')]
