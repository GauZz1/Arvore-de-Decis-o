# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('weather.nominal.csv', delimiter=',') # colect data form database

# %%
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix

# %%
X = data.drop(['play'], axis=1); # remove 'Chuva' and 'Exemplo' from 'data' and atributes to X 
Y = data['play'].map({'yes': 1, 'no': 0}); # create a new table with 'Chuva' atributte where Sim = 1 e Não = 0

xtr, Xval, ytr, yval = train_test_split(X, Y, test_size=0.5, random_state=0);

ohe = preprocessing.OneHotEncoder(sparse=False) # define OnHotEncoder

encoded_x = ohe.fit_transform(X) # transform table X to binary

arvore = DecisionTreeClassifier()
arvore = arvore.fit(encoded_x, Y) # create tree

p = arvore.predict(encoded_x)

np.sqrt(confusion_matrix(p, Y))
# Out:
# array([[2.23606798, 0.        ],
#        [0.        , 3.        ]])

# %%
plot_tree(arvore)
# Out:
# [Text(0.6, 0.9, 'X[0] <= 0.5\ngini = 0.459\nsamples = 14\nvalue = [5, 9]'),
#  Text(0.5, 0.7, 'X[7] <= 0.5\ngini = 0.5\nsamples = 10\nvalue = [5, 5]'),
#  Text(0.3, 0.5, 'X[2] <= 0.5\ngini = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(0.2, 0.3, 'X[9] <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.1, 0.1, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.3, 0.1, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.4, 0.3, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.7, 0.5, 'X[9] <= 0.5\ngini = 0.32\nsamples = 5\nvalue = [1, 4]'),
#  Text(0.6, 0.3, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.8, 0.3, 'X[1] <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.7, 0.1, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.9, 0.1, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.7, 0.7, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]')]
